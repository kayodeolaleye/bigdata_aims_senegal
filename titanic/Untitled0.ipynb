# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import os
import sys

# %%
#define the path
filename = 'data/train.csv'
os.path.exists(filename) #check if the filename exists
# Out:
# True

# %%
df = pd.read_csv(filename)

# %%
df.info() #data information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)

# %%
#Drop the missing data that is not useful
df2 = df.drop(['Age', 'Cabin', 'Embarked', 'Name', 'Sex', 'Ticket'], axis = 1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 6 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Fare           891 non-null float64
# dtypes: float64(1), int64(5)

# %%
#Plot 
# %matplotlib inline
df2.plot()

# %%
df2['Fare'].plot()

# %%
#Histogram
df2['Fare'].plot(kind = 'kde')

# %%
help(df2.plot())
# Out:
# Help on AxesSubplot in module matplotlib.axes object:
#
# class AxesSubplot(SubplotBase, Axes)
#  |  Method resolution order:
#  |      AxesSubplot
#  |      SubplotBase
#  |      Axes
#  |      matplotlib.artist.Artist
#  |      __builtin__.object
#  |
#  |  Methods inherited from SubplotBase:
#  |
#  |  __init__(self, fig, *args, **kwargs)
#  |      *fig* is a :class:`matplotlib.figure.Figure` instance.
#  |
#  |      *args* is the tuple (*numRows*, *numCols*, *plotNum*), where
#  |      the array of subplots in the figure has dimensions *numRows*,
#  |      *numCols*, and where *plotNum* is the number of the subplot
#  |      being created.  *plotNum* starts at 1 in the upper left
#  |      corner and increases to the right.
#  |
#  |
#  |      If *numRows* <= *numCols* <= *plotNum* < 10, *args* can be the
#  |      decimal integer *numRows* * 100 + *numCols* * 10 + *plotNum*.
#  |
#  |  __reduce__(self)
#  |
#  |  change_geometry(self, numrows, numcols, num)
# ...
